# %% [markdown]
# ### Michał Pogorzelec
#
# ## AiBD - Lab 2
#
# *Łączenia z bazą danych i instrukcja select*

# %%
import sqlalchemy
import psycopg2
import pandas as pd

# %%
from sqlalchemy import create_engine

db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"

db = create_engine(db_string)

connection_sqlalchemy = db.connect()

# %%
result_set = db.execute("SELECT * FROM film_category")  
for r in result_set:  
    print(r)
# Out:
# (1, 6, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (2, 11, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (3, 6, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (4, 11, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (5, 8, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (6, 9, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (7, 5, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (8, 11, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (9, 11, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (10, 15, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (11, 9, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (12, 12, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (13, 11, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (14, 4, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (15, 9, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (16, 9, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (17, 12, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (18, 2, datetime.datetime(2006, 2, 15, 10, 7, 9))
# (19, 1, datetime.datetime(2006, 2, 15, 10, 7, 9))
# ...

# %%
import psycopg2 as pg
import pandas as pd

connection = pg.connect(host='pgsql-196447.vipserv.org', port=5432, dbname='wbauer_adb', user='wbauer_adb', password='adb2020')

# %% [markdown]
# **Polecenia**
#
#
# 1. Ile kategorii filmów mamy w wypożyczalni?
# 2. Wyświetl listę kategorii w kolejności alfabetycznej.
# 3. Znajdź najstarszy i najmłodszy film do wypożyczenia.
# 4. Ile wypożyczeń odbyło się między 2005-07-01 a 2005-08-01?
# 5. Ile wypożyczeń odbyło się między 2010-01-01 a 2011-02-01?
# 6. Znajdź największą płatność wypożyczenia.
# 7. Znajdź wszystkich klientów z Polski, Nigerii lub Bangladeszu.
# 8. Gdzie mieszkają członkowie personelu?
# 9. Ilu pracowników mieszka w Argentynie lub Hiszpanii?
# 10. Jakie kategorie filmów zostały wypożyczone przez klientów?
# 11. Znajdź wszystkie kategorie filmów wypożyczonych w Ameryce.
# 12. Znajdź wszystkie tytuły filmów, w których grał: Olympia Pfeiffer lub Julia Zellweger lub Ellen Presley

# %%
# 1. Ile kategorii filmów mamy w wypożyczalni?

df = pd.read_sql('SELECT DISTINCT name FROM category',con=connection)
print(df)

# Jest 16 kategorii filmowych
# Out:
#            name
# 0        Sports
# 1      Classics
# 2           New
# 3        Family
# 4        Comedy
# 5     Animation
# 6        Travel
# 7         Music
# 8        Horror
# 9         Drama
# 10       Sci-Fi
# 11        Games
# 12  Documentary
# 13      Foreign
# 14       Action
# 15     Children
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# 2. Wyświetl listę kategorii w kolejności alfabetycznej.

df = pd.read_sql("SELECT distinct name FROM category ORDER BY name ASC",con=connection)
print(df)
# Out:
#            name
# 0        Action
# 1     Animation
# 2      Children
# 3      Classics
# 4        Comedy
# 5   Documentary
# 6         Drama
# 7        Family
# 8       Foreign
# 9         Games
# 10       Horror
# 11        Music
# 12          New
# 13       Sci-Fi
# 14       Sports
# 15       Travel
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# 3. Znajdź najstarszy i najmłodszy film do wypożyczenia.

df = pd.read_sql("SELECT release_year FROM film ORDER BY release_year ASC",con=connection)
print(df)

# Wszystkie filmy zostały wypożyczone w tym samym roku
# Out:
#      release_year
# 0            2006
# 1            2006
# 2            2006
# 3            2006
# 4            2006
# ..            ...
# 995          2006
# 996          2006
# 997          2006
# 998          2006
# 999          2006
#
# [1000 rows x 1 columns]
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# 4. Ile wypożyczeń odbyło się między 2005-07-01 a 2005-08-01?

df = pd.read_sql("SELECT rental_date FROM rental WHERE rental_date between '2005-07-01' AND '2005-08-01'",con=connection)
print(df)

# 6709 wypożyczeń
# Out:
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#              rental_date
# 0    2005-07-05 22:49:24
# 1    2005-07-05 22:51:44
# 2    2005-07-05 22:56:33
# 3    2005-07-05 22:57:34
# 4    2005-07-05 22:59:53
# ...                  ...
# 6704 2005-07-31 23:40:35
# 6705 2005-07-31 23:42:33
# 6706 2005-07-31 23:43:04
# 6707 2005-07-31 23:49:54
# 6708 2005-07-31 23:57:43
#
# [6709 rows x 1 columns]

# %%
# 5. Ile wypożyczeń odbyło się między 2010-01-01 a 2011-02-01?

df = pd.read_sql("SELECT rental_date FROM rental WHERE rental_date between '2010-01-01' AND '2011-02-01'",con=connection)
print(df)

# 0 wypożyczeń
# Out:
# Empty DataFrame
# Columns: [rental_date]
# Index: []
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# 6. Znajdź największą płatność wypożyczenia.

df = pd.read_sql("SELECT amount FROM payment ORDER BY amount ASC",con=connection)
print(df)

# Największa płatność 11.99$
# Out:
#        amount
# 0        0.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        0.00
# ...       ...
# 14591   11.99
# 14592   11.99
# 14593   11.99
# 14594   11.99
# 14595   11.99
#
# [14596 rows x 1 columns]
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# 7. Znajdź wszystkich klientów z Polski, Nigerii lub Bangladeszu.

df = pd.read_sql("SELECT customer.customer_id, city.city, country.country FROM city INNER JOIN country ON \
                 city.country_id = country.country_id INNER JOIN address ON address.city_id = city.city_id \
                 INNER JOIN customer ON customer.address_id = address.address_id \
                 WHERE country IN ('Poland', 'Nigeria', 'Bangladesh') ", con=connection)
print(df)

# 24 klientów z tych 3 państw
# Out:
#     customer_id             city     country
# 0           284       Benin City     Nigeria
# 1           318        Bydgoszcz      Poland
# 2           572      Czestochowa      Poland
# 3           409        Deba Habe     Nigeria
# 4           332            Dhaka  Bangladesh
# 5           286     Effon-Alaiye     Nigeria
# 6            80              Ife     Nigeria
# 7           198           Ikerre     Nigeria
# 8           103           Ilorin     Nigeria
# 9           329         Jamalpur  Bangladesh
# 10          128  Jastrzebie-Zdrj      Poland
# 11           18           Kaduna     Nigeria
# 12          270           Kalisz      Poland
# 13          501           Lublin      Poland
# 14          277        Ogbomosho     Nigeria
# 15          156             Ondo     Nigeria
# 16          280              Owo     Nigeria
# 17          250              Oyo     Nigeria
# 18          571            Plock      Poland
# 19          562           Sokoto     Nigeria
# ...

# %%
# 8. Gdzie mieszkają członkowie personelu?

df = pd.read_sql("SELECT staff.first_name, staff.last_name, staff.staff_id, address.address FROM staff INNER JOIN address ON \
                staff.address_id = address.address_id", con=connection)
print(df)
# Out:
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   first_name last_name  staff_id               address
# 0       Mike   Hillyer         1     23 Workhaven Lane
# 1        Jon  Stephens         2  1411 Lillydale Drive

# %%
# 9. Ilu pracowników mieszka w Argentynie lub Hiszpanii?

df = pd.read_sql("SELECT DISTINCT ON (staff.staff_id) staff.staff_id, staff.first_name, staff.last_name, country.country FROM staff\
                INNER JOIN address ON staff.address_id = address.address_id INNER JOIN city ON address.city_id = city.city_id \
                INNER JOIN country ON city.country_id = country.country_id \
                WHERE country IN ('Spain', 'Argentina')", con=connection)
print(df)

# 0
# Out:
# Empty DataFrame
# Columns: [staff_id, first_name, last_name, country]
# Index: []
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df = pd.read_sql("SELECT staff.staff_id, staff.address_id, city.city, country.country FROM staff \
INNER JOIN address ON staff.address_id = address.address_id \
INNER JOIN city ON address.city_id = city.city_id INNER JOIN country ON city.country_id = country.country_id", con=connection)
print(df)

# Pracownicy mieszkają w Australii i Kanadzie
# Out:
#    staff_id  address_id        city    country
# 0         1           3  Lethbridge     Canada
# 1         2           4   Woodridge  Australia
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# 10. Jakie kategorie filmów zostały wypożyczone przez klientów?

df = pd.read_sql("SELECT DISTINCT ON (category.name) category.name FROM rental \
INNER JOIN inventory ON rental.inventory_id = inventory.inventory_id \
INNER JOIN film ON inventory.film_id = film.film_id \
INNER JOIN film_category ON film.film_id = film_category.film_id \
INNER JOIN category ON film_category.category_id = category.category_id", con=connection)
print(df)
# Out:
#            name
# 0        Action
# 1     Animation
# 2      Children
# 3      Classics
# 4        Comedy
# 5   Documentary
# 6         Drama
# 7        Family
# 8       Foreign
# 9         Games
# 10       Horror
# 11        Music
# 12          New
# 13       Sci-Fi
# 14       Sports
# 15       Travel
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# 11. Znajdź wszystkie kategorie filmów wypożyczonych w Ameryce.

df = pd.read_sql("SELECT DISTINCT ON (category.name) category.name, country.country FROM rental \
INNER JOIN inventory ON rental.inventory_id = inventory.inventory_id \
INNER JOIN film ON inventory.film_id = film.film_id \
INNER JOIN film_category ON film.film_id = film_category.film_id \
INNER JOIN category ON film_category.category_id = category.category_id \
INNER JOIN customer ON rental.customer_id = customer.customer_id \
INNER JOIN address ON customer.address_id = address.address_id \
INNER JOIN city ON address.city_id = city.city_id \
INNER JOIN country ON city.country_id = country.country_id WHERE country.country = 'United States' ", con=connection)
print(df)

# wyświetlają się wszystkie kategorie, to znaczy że wszystkie kategorie zostały wypozyczone w USA - dla sprawdzenia można wpisać
# np. Tunisia i zobaczyć, że wyświetli się mniej kategorii
# Out:
#            name        country
# 0        Action  United States
# 1     Animation  United States
# 2      Children  United States
# 3      Classics  United States
# 4        Comedy  United States
# 5   Documentary  United States
# 6         Drama  United States
# 7        Family  United States
# 8       Foreign  United States
# 9         Games  United States
# 10       Horror  United States
# 11        Music  United States
# 12          New  United States
# 13       Sci-Fi  United States
# 14       Sports  United States
# 15       Travel  United States
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# 12. Znajdź wszystkie tytuły filmów, w których grał: Olympia Pfeiffer lub Julia Zellweger lub Ellen Presley

df = pd.read_sql("SELECT film.title, actor.first_name, actor.last_name FROM film \
INNER JOIN film_actor ON film.film_id = film_actor.film_id \
INNER JOIN actor ON film_actor.actor_id = actor.actor_id WHERE (actor.first_name = 'Olympia' AND actor.last_name = 'Pfeiffer')\
OR (actor.first_name = 'Julia' AND actor.last_name = 'Zellweger') \
OR (actor.first_name = 'Ellen' AND actor.last_name = 'Presley')\
LIMIT 40 OFFSET 20", con=connection) # dodany limit z offsetem żeby było widać nazwiska wszystkich 3 aktorów
print(df)
# Out:
# D:\anaconda\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#                      title first_name  last_name
# 0     Streetcar Intentions      Ellen    Presley
# 1             Tadpole Park      Ellen    Presley
# 2         Treasure Command      Ellen    Presley
# 3                Turn Star      Ellen    Presley
# 4             Women Dorado      Ellen    Presley
# 5              Badman Dawn    Olympia   Pfeiffer
# 6              Chitty Lock    Olympia   Pfeiffer
# 7       Color Philadelphia    Olympia   Pfeiffer
# 8        Contact Anonymous    Olympia   Pfeiffer
# 9             Deep Crusade    Olympia   Pfeiffer
# 10        Effect Gladiator    Olympia   Pfeiffer
# 11          Express Lonely    Olympia   Pfeiffer
# 12       Firehouse Vietnam    Olympia   Pfeiffer
# ...
